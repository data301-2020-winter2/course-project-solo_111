# %% [markdown]
# ## Importing and Cleaning the Raw Data
# My raw data goes through the following changes once put through the **load_process** function:
# - Replace all blank values as nan
# - Drop all rows with nan in them
# - Reset the index of the no-nan dataframe
# - Rename each column since they have slight errors to them
# - Convert Cocoa Percentage from a string to a float
# - Copy the processed data file to its respective folder

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from Scripts.function import load_process
from Scripts.function import make_table

# %%
df = load_process("../data/raw/flavors_of_cacao.csv")
df
# Out:
#     Company (Maker-if known) Specific Bean Origin or Bar Name   REF  \
# 0                   A. Morin                         Carenero  1315
# 1                   A. Morin                     Sur del Lago  1315
# 2                   A. Morin                   Puerto Cabello  1319
# 3                   A. Morin                       Madagascar  1011
# 4                   A. Morin                            Chuao  1015
# ..                       ...                              ...   ...
# 879                   Zotter                           El Oro   879
# 880                   Zotter                     Huiwani Coop   879
# 881                   Zotter                 Kongo, Highlands   883
# 882                   Zotter                            Congo   749
# 883                   Zotter                     Kerala State   749
#
#      Review Date  Cocoa Percent Company Location  Rating  \
# 0           2014           0.70           France    2.75
# 1           2014           0.70           France    3.50
# 2           2014           0.70           France    3.75
# 3           2013           0.70           France    3.00
# 4           2013           0.70           France    4.00
# ..           ...            ...              ...     ...
# 879         2012           0.75          Austria    3.00
# 880         2012           0.75          Austria    3.00
# 881         2012           0.68          Austria    3.25
# 882         2011           0.65          Austria    3.00
# 883         2011           0.65          Austria    3.50
#
#                 Bean Type Broad Bean Origin
# 0                 Criollo         Venezuela
# 1                 Criollo         Venezuela
# 2                 Criollo         Venezuela
# 3                 Criollo        Madagascar
# 4              Trinitario         Venezuela
# ..                    ...               ...
# 879  Forastero (Nacional)           Ecuador
# 880   Criollo, Trinitario  Papua New Guinea
# 881             Forastero             Congo
# 882             Forastero             Congo
# 883             Forastero             India
#
# [884 rows x 9 columns]

# %% [markdown]
# ## Profile Report
# Creating a profile report gives me a nice overview of my data and lets me narrow down what data I will compare in my EDA

# %%
import pandas_profiling as pdp

# %%
profile = pdp.ProfileReport(df)
profile

# %% [markdown]
# #### Observations:
# - BLEH
# - BLAH
# - MEH

# %% [markdown]
# ## Bean Type Analysis:

# %% [markdown]
# #### Table:
# Ordered the Bean Type by mean rating.

# %%
beanType = make_table(df,"Bean Type")
beanType
# Out:
#                    Bean Type    Rating
# 0       Criollo (Ocumare 67)  4.000000
# 1             Criollo (Wild)  4.000000
# 2   Trinitario (85% Criollo)  3.875000
# 3      Forastero (Amelonado)  3.750000
# 4       Trinitario, Nacional  3.750000
# 5                 Amazon mix  3.750000
# 6       Criollo (Ocumare 77)  3.750000
# 7           Trinitario, TCGA  3.750000
# 8    Blend-Forastero,Criollo  3.750000
# 9                Amazon, ICS  3.625000
# 10        Criollo, Forastero  3.625000
# 11                       EET  3.583333
# 12                   Beniano  3.583333
# 13     Forastero (Parazinho)  3.531250
# 14                     CCN51  3.500000
# 15      Trinitario (Scavina)  3.500000
# 16                Criollo, +  3.500000
# 17   Forastero (Arriba) ASSS  3.500000
# 18                    Matina  3.416667
# 19       Forastero (Catongo)  3.375000
# 20       Criollo (Porcelana)  3.375000
# 21       Criollo, Trinitario  3.294872
# 22      Forastero (Nacional)  3.269231
# 23         Nacional (Arriba)  3.250000
# 24          Criollo (Amarru)  3.250000
# 25      Criollo (Ocumare 61)  3.250000
# 26                    Amazon  3.250000
# 27                Trinitario  3.247002
# 28                   Criollo  3.245066
# 29                     Blend  3.214286
# 30                 Forastero  3.100575
# 31       Trinitario, Criollo  3.027778
# 32    Forastero(Arriba, CCN)  3.000000
# 33     Forastero, Trinitario  3.000000
# 34                  Nacional  3.000000
# 35    Trinitario (Amelonado)  3.000000
# 36         Criollo (Ocumare)  3.000000
# 37     Trinitario, Forastero  3.000000
# 38    Forastero (Arriba) ASS  2.875000
# 39        Forastero (Arriba)  2.831081

# %% [markdown]
# #### Graph Visual:
# Converted the table above into a visual.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20,5)
ax = plt.gca()
plt.xticks(rotation=90)
sns.barplot(data=beanType,
            x='Bean Type',
            y='Rating').set_title("Bean Type Sorted by Rating")
# Out:
# Text(0.5, 1.0, 'Bean Type Sorted by Rating')

# %% [markdown]
# #### Observations:
# - There is a clear sign that bean type has some influence on a chocolate bars rating.
# - If the bean type didn't influence rating, then the bar plot would be much more flat.
# - According to the visual, bean type can possibly influence the overall rating by nearly a whole point.

# %% [markdown]
# ## Cocoa Percentage Analysis:

# %% [markdown]
# #### Table:
# Ordered the Cocoa Percentage by mean rating.

# %%
cocoaP = make_table(df,'Cocoa Percent')
cocoaP
# Out:
#     Cocoa Percent    Rating
# 0           0.500  3.750000
# 1           0.690  3.562500
# 2           0.630  3.437500
# 3           0.700  3.360927
# 4           0.740  3.340000
# 5           0.680  3.294643
# 6           0.780  3.291667
# 7           0.730  3.291667
# 8           0.660  3.272727
# 9           0.670  3.264706
# 10          0.860  3.250000
# 11          0.650  3.250000
# 12          0.640  3.218750
# 13          0.720  3.217172
# 14          0.750  3.206612
# 15          0.580  3.200000
# 16          0.820  3.136364
# 17          0.735  3.125000
# 18          0.760  3.083333
# 19          0.600  3.083333
# 20          0.880  3.083333
# 21          0.810  3.062500
# 22          0.850  3.053571
# 23          0.800  3.047297
# 24          0.710  3.000000
# 25          0.830  3.000000
# 26          0.840  3.000000
# 27          0.770  2.977273
# 28          0.620  2.916667
# 29          0.550  2.906250
# 30          0.610  2.833333
# 31          0.890  2.750000
# 32          0.900  2.750000
# 33          0.725  2.750000
# 34          0.605  2.750000
# 35          0.570  2.750000
# 36          1.000  2.194444
# 37          0.530  2.000000
# 38          0.910  1.750000

# %% [markdown]
# #### Graph Visual:
# Converted the table above into a visual.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(25,5)
sns.barplot(data=cocoaP,
            x='Cocoa Percent',
            y='Rating').set_title("Cocoa Percent VS Rating")
# Out:
# Text(0.5, 1.0, 'Cocoa Percent VS Rating')

# %% [markdown]
# #### Observations:
# - It's hard to tell if cocoa percentage truly has any effect on overall rating since there is no clear trend or slope that would indicate so.
# - This makes sense due to the fact that cocoa percentages are more reflective of the type of chocolate, not the quality. For example, milk chocolate is made with a low cocoa percentage yet can still be high quality.
# - According to the visual, cocoa percentage doesn't have much of an effect on rating.

# %% [markdown]
# ## Company/Maker Analysis:

# %% [markdown]
# #### Table:
# Ordered the Company/Maker by mean rating.

# %%
company = make_table(df,'Company (Maker-if known)')
company
# Out:
#                  Company (Maker-if known)  Rating
# 0                  Tobago Estate (Pralus)  4.0000
# 1    Heirloom Cacao Preservation (Zokoko)  3.8750
# 2                                  Ocelot  3.8750
# 3                         Bar Au Chocolat  3.8750
# 4                                  Matale  3.8125
# ..                                    ...     ...
# 277                Bouga Cacao (Tulicorp)  2.3750
# 278                               C-Amaro  2.3750
# 279                     Snake & Butterfly  2.2500
# 280                                  TCHO  2.2500
# 281                         Jacque Torres  2.0000
#
# [282 rows x 2 columns]

# %% [markdown]
# #### Graph Visual:
# Converted the table above into a visual.

# %%
ax = plt.gca()
ax.axes.xaxis.set_visible(False)
sns.barplot(data=company,
            x='Company (Maker-if known)',
            y='Rating').set_title("Company/Maker Sorted by Rating")
# Out:
# Text(0.5, 1.0, 'Company/Maker Sorted by Rating')

# %% [markdown]
# #### Observations:
# - There is a clear sign that Company/Maker has an influence on a chocolate bars rating.
# - It should be noted that unlike the bean type visual, company seems to have a greater influence as it is nearly twice as steep.
# - According to the visual, Company/Maker can possibly influence the overall rating by nearly 2 whole points.

# %% [markdown]
# ## Bean Origin Analysis:

# %% [markdown]
# #### Table:
# Ordered the Bean Origin by mean rating.

# %%
beanOrig = make_table(df,'Broad Bean Origin')
beanOrig
# Out:
#               Broad Bean Origin    Rating
# 0                        Tobago  4.000000
# 1   Gre., PNG, Haw., Haiti, Mad  4.000000
# 2               Venezuela, Java  4.000000
# 3         Dom. Rep., Madagascar  4.000000
# 4             DR, Ecuador, Peru  3.750000
# ..                          ...       ...
# 61                       Uganda  2.821429
# 62                    Sri Lanka  2.750000
# 63                     Principe  2.750000
# 64                  West Africa  2.583333
# 65           Ghana & Madagascar  2.000000
#
# [66 rows x 2 columns]

# %% [markdown]
# #### Graph Visual:
# Converted the table above into a visual.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(25,5)
ax = plt.gca()
plt.xticks(rotation=90)
sns.barplot(data=beanOrig,
            x='Broad Bean Origin',
            y='Rating').set_title("Bean Origin Sorted by Rating")
# Out:
# Text(0.5, 1.0, 'Bean Origin Sorted by Rating')

# %% [markdown]
# #### Observations:
# - There is a clear sign that Bean Origin has an influence on a chocolate bars rating. Some countries/combinations of countries yield higher rating chocolate than others.
# - Much like the bean type, if the bean origin didn't influence rating, then the bar plot would be much more flat.
# - According to the visual, Bean Origin can possibly influence the overall rating by nearly 1.5 points.

# %% [markdown]
# ## Answering Research Questions:

# %% [markdown]
# #### Does cocoa bean type influence a bars rating?

# %% [markdown]
# #### Does cocoa percentage influence a bars rating?

# %% [markdown]
# #### Does chocolate company/maker influence a bars rating?

# %% [markdown]
# #### Does bean origin influence a bars rating?
